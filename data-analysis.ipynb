# %%
import pandas as pd
from pyproj import Transformer
import geojson

# %%
df = pd.read_csv('data/fulldata_01_01_01_P_병원.csv', encoding='cp949')
df.head()
# Out:
#    번호 개방서비스명    개방서비스아이디  개방자치단체코드                       관리번호       인허가일자  \
# 0   1     병원  01_01_01_P   5340000  PHMA220125340030021200003  2012-11-30
# 1   2     병원  01_01_01_P   5340000  PHMA220135340030021200001  2013-11-11
# 2   3     병원  01_01_01_P   5340000  PHMA220165340030021200001  2016-01-28
# 3   4     병원  01_01_01_P   5380000  PHMA219895380021021200001  1989-03-31
# 4   5     병원  01_01_01_P   5410000  PHMA220185410012021200001  2018-03-16
#
#    인허가취소일자  영업상태구분코드  영업상태명 상세영업상태코드  ... 완화의료지정형태 완화의료담당부서명 구급차특수 구급차일반  총인원  \
# 0      NaN         1  영업/정상       13  ...      NaN       NaN     0     0  NaN
# 1      NaN         1  영업/정상       13  ...      NaN       NaN     0     0  NaN
# 2      NaN         1  영업/정상       13  ...      NaN       NaN     0     0  NaN
# 3      NaN         1  영업/정상       13  ...      NaN       NaN     0     0  NaN
# 4      NaN         1  영업/정상       13  ...      NaN       NaN     0     0  NaN
#
#   구조사수  허가병상수 최초지정일자 관리주체 Unnamed: 45
# ...

# %%
df.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(x)', '좌표정보(y)',
#        '의료기관종별명', '의료인수', '입원실수', '병상수', '총면적', '진료과목내용', '진료과목내용명', '지정취소일자',
#        '완화의료지정형태', '완화의료담당부서명', '구급차특수', '구급차일반', '총인원', '구조사수', '허가병상수',
#        '최초지정일자', '관리주체', 'Unnamed: 45'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8738 entries, 0 to 8737
# Data columns (total 46 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   번호           8738 non-null   int64
#  1   개방서비스명       8738 non-null   object
#  2   개방서비스아이디     8738 non-null   object
#  3   개방자치단체코드     8738 non-null   int64
#  4   관리번호         8738 non-null   object
#  5   인허가일자        8738 non-null   object
#  6   인허가취소일자      0 non-null      float64
#  7   영업상태구분코드     8738 non-null   int64
#  8   영업상태명        8738 non-null   object
#  9   상세영업상태코드     8738 non-null   object
#  10  상세영업상태명      8591 non-null   object
#  11  폐업일자         3032 non-null   object
#  12  휴업시작일자       293 non-null    object
#  13  휴업종료일자       289 non-null    object
#  14  재개업일자        0 non-null      float64
#  15  소재지전화        8292 non-null   object
#  16  소재지면적        4887 non-null   float64
#  17  소재지우편번호      2487 non-null   object
# ...

# %%
df = df[['영업상태명', '도로명전체주소', '도로명우편번호', '사업장명', '최종수정시점', '데이터갱신일자', '업태구분명', '좌표정보(x)', '좌표정보(y)', '의료인수', '진료과목내용명']]
df.head()
# Out:
#    영업상태명                         도로명전체주소 도로명우편번호                   사업장명  \
# 0  영업/정상      경상남도 사천시 사천읍 옥산로 127, 3~7층   52517  의료법인 행복한의료재단 사천중앙요양병원
# 1  영업/정상           경상남도 사천시 사천읍 구암두문로 74   52517                 사천동희병원
# 2  영업/정상     경상남도 사천시 각산로 86 (서동, 미진예식장)   52556     의료법인 삼포의료재단 현대요양병원
# 3  영업/정상         경상남도 양산시 모래들1길 91 (주진동)   50521                   양산병원
# 4  영업/정상  경상남도 창녕군 고암면 상대2길 16, 더케이서드에이지   50315                프라임요양병원
#
#                 최종수정시점              데이터갱신일자         업태구분명        좌표정보(x)  \
# 0  2023-10-30 09:30:06  2023-11-01 02:40:00  요양병원(일반요양병원)  299970.331817
# 1  2024-10-04 02:13:26  2024-10-06 02:40:00          정신병원  299722.420372
# 2  2024-08-08 11:29:27  2024-08-10 02:40:00  요양병원(일반요양병원)  297272.390841
# 3  2024-09-27 09:13:26  2024-09-29 02:40:00          정신병원  395040.472611
# 4  2024-10-18 10:55:57  2024-10-20 02:40:00  요양병원(일반요양병원)  337000.344450
#
#          좌표정보(y)  의료인수                                            진료과목내용명
# ...

# %%
df['업태구분명'].unique()
# Out:
# array(['요양병원(일반요양병원)', '정신병원', '병원', '요양병원(노인병원)', '치과병원', '종합병원', '한방병원',
#        '요양병원(장애인의료재활시설)', '요양병원(정신병원)', nan], dtype=object)

# %%
df['영업상태명'].unique()
# Out:
# array(['영업/정상', '취소/말소/만료/정지/중지', '폐업', '휴업'], dtype=object)

# %%
df = df[df['영업상태명'] == '영업/정상']
df.head()
# Out:
#    영업상태명                         도로명전체주소 도로명우편번호                   사업장명  \
# 0  영업/정상      경상남도 사천시 사천읍 옥산로 127, 3~7층   52517  의료법인 행복한의료재단 사천중앙요양병원
# 1  영업/정상           경상남도 사천시 사천읍 구암두문로 74   52517                 사천동희병원
# 2  영업/정상     경상남도 사천시 각산로 86 (서동, 미진예식장)   52556     의료법인 삼포의료재단 현대요양병원
# 3  영업/정상         경상남도 양산시 모래들1길 91 (주진동)   50521                   양산병원
# 4  영업/정상  경상남도 창녕군 고암면 상대2길 16, 더케이서드에이지   50315                프라임요양병원
#
#                 최종수정시점              데이터갱신일자         업태구분명        좌표정보(x)  \
# 0  2023-10-30 09:30:06  2023-11-01 02:40:00  요양병원(일반요양병원)  299970.331817
# 1  2024-10-04 02:13:26  2024-10-06 02:40:00          정신병원  299722.420372
# 2  2024-08-08 11:29:27  2024-08-10 02:40:00  요양병원(일반요양병원)  297272.390841
# 3  2024-09-27 09:13:26  2024-09-29 02:40:00          정신병원  395040.472611
# 4  2024-10-18 10:55:57  2024-10-20 02:40:00  요양병원(일반요양병원)  337000.344450
#
#          좌표정보(y)  의료인수                                            진료과목내용명
# ...

# %%
transformer = Transformer.from_crs("epsg:2097", "epsg:4326")
transformer
# Out:
# <Concatenated Operation Transformer: pipeline>
# Description: Inverse of Korea Central Belt + Korean 1985 to WGS 84 (1)
# Area of Use:
# - name: Republic of Korea (South Korea) - onshore.
# - bounds: (124.53, 33.14, 131.01, 38.64)

# %%
df["lat"], df["lon"] = zip(*df.apply(lambda row: transformer.transform(row["좌표정보(y)"], row["좌표정보(x)"]), axis=1))
df.head()
# Out:
#    영업상태명                         도로명전체주소 도로명우편번호                   사업장명  \
# 0  영업/정상      경상남도 사천시 사천읍 옥산로 127, 3~7층   52517  의료법인 행복한의료재단 사천중앙요양병원
# 1  영업/정상           경상남도 사천시 사천읍 구암두문로 74   52517                 사천동희병원
# 2  영업/정상     경상남도 사천시 각산로 86 (서동, 미진예식장)   52556     의료법인 삼포의료재단 현대요양병원
# 3  영업/정상         경상남도 양산시 모래들1길 91 (주진동)   50521                   양산병원
# 4  영업/정상  경상남도 창녕군 고암면 상대2길 16, 더케이서드에이지   50315                프라임요양병원
#
#                 최종수정시점              데이터갱신일자         업태구분명        좌표정보(x)  \
# 0  2023-10-30 09:30:06  2023-11-01 02:40:00  요양병원(일반요양병원)  299970.331817
# 1  2024-10-04 02:13:26  2024-10-06 02:40:00          정신병원  299722.420372
# 2  2024-08-08 11:29:27  2024-08-10 02:40:00  요양병원(일반요양병원)  297272.390841
# 3  2024-09-27 09:13:26  2024-09-29 02:40:00          정신병원  395040.472611
# 4  2024-10-18 10:55:57  2024-10-20 02:40:00  요양병원(일반요양병원)  337000.344450
#
#          좌표정보(y)  의료인수                                            진료과목내용명  \
# ...

# %%
df = df.rename(columns={
    '영업상태명': 'business_status',
    '도로명전체주소': 'address',
    '도로명우편번호': 'zipcode',
    '사업장명': 'name',
    '최종수정시점': 'last_modified_date',
    '데이터갱신일자': 'updated_date',
    '업태구분명': 'business_type',
    '좌표정보(x)': 'x(epsg:2097)',
    '좌표정보(y)': 'y(epsg:4326)',
    '의료인수': 'medical_personnel',
    '진료과목내용명': 'department_content'
})
df.head()
# Out:
#   business_status                         address zipcode  \
# 0           영업/정상      경상남도 사천시 사천읍 옥산로 127, 3~7층   52517
# 1           영업/정상           경상남도 사천시 사천읍 구암두문로 74   52517
# 2           영업/정상     경상남도 사천시 각산로 86 (서동, 미진예식장)   52556
# 3           영업/정상         경상남도 양산시 모래들1길 91 (주진동)   50521
# 4           영업/정상  경상남도 창녕군 고암면 상대2길 16, 더케이서드에이지   50315
#
#                     name   last_modified_date         updated_date  \
# 0  의료법인 행복한의료재단 사천중앙요양병원  2023-10-30 09:30:06  2023-11-01 02:40:00
# 1                 사천동희병원  2024-10-04 02:13:26  2024-10-06 02:40:00
# 2     의료법인 삼포의료재단 현대요양병원  2024-08-08 11:29:27  2024-08-10 02:40:00
# 3                   양산병원  2024-09-27 09:13:26  2024-09-29 02:40:00
# 4                프라임요양병원  2024-10-18 10:55:57  2024-10-20 02:40:00
#
#   business_type   x(epsg:2097)   y(epsg:4326)  medical_personnel  \
# 0  요양병원(일반요양병원)  299970.331817  176114.707951                 23
# 1          정신병원  299722.420372  177131.778303                 18
# ...

# %%
df = df.drop(columns=['business_status', 'business_type', 'x(epsg:2097)', 'y(epsg:4326)', 'medical_personnel'])
df.tail()
# Out:
#                                                 address zipcode  \
# 7970                   전라남도 목포시 백년대로 258-0,  (상동)층 (상동)     NaN
# 7971                     충청북도 괴산군 칠성면 자연드림길 223-0, 병원동층     NaN
# 7972  강원특별자치도 태백시 보드미길 8-0,  4층 (장성동,근로복지공단태백요양병원)층 ...     NaN
# 7973          충청북도 충주시 국원대로 99-0,  0동 (교현동,미래병원)층 (교현동)     NaN
# 7974                   대전광역시 서구 둔산로 61-0,  (둔산동)층 (둔산동)     NaN
#
#                name   last_modified_date         updated_date  \
# 7970        목포신세계병원  2023-07-19 17:35:12  2023-07-21 02:40:00
# 7971  아이쿱 재발방지 요양병원  2024-09-13 09:46:46  2024-09-15 02:40:00
# 7972  근로복지공단 태백요양병원  2024-10-30 10:22:37  2024-11-01 02:40:00
# 7973         충주미래병원  2024-07-02 17:00:02  2024-07-04 02:40:00
# 7974       밝은누리안과병원  2024-10-18 10:13:17  2024-10-20 02:40:00
#
#      deparment_content        lat         lon
# 7970               NaN  34.801697  126.413812
# 7971               NaN        NaN         NaN
# 7972               NaN  37.103983  129.001306
# ...

# %%
df = df[df['lat'].notna()]
df = df[df['lon'].notna()]
df.tail()
# Out:
#                                                 address zipcode  \
# 7969     대전광역시 유성구 온천동로 43-0, 본관지하1~3층,9층/신관2~3층층 (봉명동)     NaN
# 7970                   전라남도 목포시 백년대로 258-0,  (상동)층 (상동)     NaN
# 7972  강원특별자치도 태백시 보드미길 8-0,  4층 (장성동,근로복지공단태백요양병원)층 ...     NaN
# 7973          충청북도 충주시 국원대로 99-0,  0동 (교현동,미래병원)층 (교현동)     NaN
# 7974                   대전광역시 서구 둔산로 61-0,  (둔산동)층 (둔산동)     NaN
#
#                        name   last_modified_date         updated_date  \
# 7969  의료법인 밝은마음의료재단 워크런재활병원  2024-10-18 10:14:28  2024-10-20 02:40:00
# 7970                목포신세계병원  2023-07-19 17:35:12  2023-07-21 02:40:00
# 7972          근로복지공단 태백요양병원  2024-10-30 10:22:37  2024-11-01 02:40:00
# 7973                 충주미래병원  2024-07-02 17:00:02  2024-07-04 02:40:00
# 7974               밝은누리안과병원  2024-10-18 10:13:17  2024-10-20 02:40:00
#
#      deparment_content        lat         lon
# 7969               NaN  36.355380  127.347746
# 7970               NaN  34.801697  126.413812
# ...

# %%
df['address'].isnull().sum(), df['zipcode'].isnull().sum(), df['name'].isnull().sum(), df['last_modified_date'].isnull().sum(), df['department_content'].isnull().sum()
# Out:
# (np.int64(74), np.int64(1367), np.int64(0), np.int64(0), np.int64(864))

# %%
features = []
for _, row in df.iterrows():
    point = geojson.Point((row["lon"], row["lat"]))
    properties = {
        "name": row["name"],
        "address": row["address"] if not pd.isna(row["address"]) else "",
        "last_modified_date": row["last_modified_date"] if not pd.isna(row["last_modified_date"]) else "",
        "updated_date": row["updated_date"] if not pd.isna(row["updated_date"]) else "",
        "department_content": row["department_content"] if not pd.isna(row["department_content"]) else ""
    }
    features.append(geojson.Feature(geometry=point, properties=properties))

feature_collection = geojson.FeatureCollection(features)

# %%
with open("kr_medical_institutions.geojson", "w", encoding="utf-8") as f:
    geojson.dump(feature_collection, f, ensure_ascii=False)
